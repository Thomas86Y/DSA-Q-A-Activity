# %% [markdown]
# #  Read the dataset to python environment

# %%
import pandas as pd
iris = pd.read_excel("C:/Users/thoma/Downloads/Paatshala Assignments/iris.xls")

# %% [markdown]
# # 2. Display the columns in the dataset.

# %%
iris
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 3. Calculate the mean of each column of the dataset.

# %%
import numpy as np

# %%
iris.iloc[:,0:4].apply(np.mean)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4. Check for the null values present in the dataset.

# %%
iris.isnull().any()
# Out:
# SL                False
# SW                False
# PL                False
# PW                False
# Classification    False
# dtype: bool

# %% [markdown]
# # 5. Perform meaningful visualizations using the dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(color_codes=True)

# %%
sns.barplot(iris['SL'],iris['PL'])
# Out:
# C:\Users\thoma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SL', ylabel='PL'>

# %%
sns.stripplot(iris['SL'],iris['PL'])
# Out:
# C:\Users\thoma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SL', ylabel='PL'>

# %%
sns.jointplot(iris['SW'],iris['PW'])
# Out:
# C:\Users\thoma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(iris[['SL','PL','SW','PW']])

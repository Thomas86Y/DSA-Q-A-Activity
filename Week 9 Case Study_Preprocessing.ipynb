# %% [markdown]
# # 1. Load the dataset into python environment

# %%
import pandas as pd
import numpy as np

# %%
tit = pd.read_csv("titanic_dataset.csv")
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # 2. Make ‘PassengerId’ as the index column

# %%
tit = pd.read_csv("titanic_dataset.csv", index_col = "PassengerId")
tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# # 3. Check the basic details of the dataset

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
tit.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
tit.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # 4. Fill in all the missing values present in all the columns in the dataset

# %%
tit[["Age","Cabin","Embarked"]]
# Out:
#               Age Cabin Embarked
# PassengerId
# 1            22.0   NaN        S
# 2            38.0   C85        C
# 3            26.0   NaN        S
# 4            35.0  C123        S
# 5            35.0   NaN        S
# ...           ...   ...      ...
# 887          27.0   NaN        S
# 888          19.0   B42        S
# 889           NaN   NaN        S
# 890          26.0  C148        C
# 891          32.0   NaN        Q
#
# [891 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
dt = tit[["Age"]] 
dt.hist(figsize = (12,6))
plt.show()

# %% [markdown]
# Age with mean , Embarked with Mode , Cabin is removed by drop

# %%
tit["Age"]      = tit["Age"].fillna(tit["Age"].median())
tit["Embarked"] = tit["Embarked"].fillna(tit["Embarked"].mode().loc[0])
tit.drop(["Cabin"],axis = 1,inplace = True)

# %%
tit
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
tit.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# # 5. Check and handle outliers in at least 3 columns in the datase

# %% [markdown]
# Checking Outliers of age

# %%
plt.boxplot(tit["Age"])
plt.title("Checking outliers")
# Out:
# Text(0.5, 1.0, 'Checking outliers')

# %%
Q1 = np.percentile(tit["Age"], 25)
Q2 = np.percentile(tit["Age"], 50)
Q3 = np.percentile(tit["Age"], 75)
IQR = Q3 - Q1
low_lim = Q1 - 1.5*IQR
Up_lim  = Q3 + 1.5*IQR

# %%
print(low_lim)
print(Up_lim)
# Out:
# 2.5
# 54.5

# %%
Outlier= []
for i in tit["Age"]:
    if((i > Up_lim)  or (i < low_lim)):
        Outlier.append(i)

# %%
Outlier
# Out:
# [2.0,
#  58.0,
#  55.0,
#  2.0,
#  66.0,
#  65.0,
#  0.83,
#  59.0,
#  71.0,
#  70.5,
#  2.0,
#  55.5,
#  1.0,
#  61.0,
#  1.0,
#  56.0,
#  1.0,
#  58.0,
#  2.0,
#  59.0,
#  62.0,
#  58.0,
#  63.0,
#  65.0,
#  2.0,
#  0.92,
#  61.0,
#  2.0,
#  60.0,
#  1.0,
#  1.0,
#  64.0,
#  65.0,
#  56.0,
#  0.75,
#  2.0,
#  63.0,
#  58.0,
#  55.0,
#  71.0,
#  2.0,
#  64.0,
#  62.0,
#  62.0,
#  60.0,
#  61.0,
#  57.0,
#  80.0,
#  2.0,
#  0.75,
#  56.0,
#  58.0,
#  70.0,
#  60.0,
#  60.0,
#  70.0,
#  0.67,
#  57.0,
#  1.0,
#  0.42,
#  2.0,
#  1.0,
#  62.0,
#  0.83,
#  74.0,
#  56.0]

# %%
ind_1 =tit["Age"] > Up_lim
tit.loc[ind_1].index
# Out:
# Int64Index([ 12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
#             269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
#             556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
#             830, 852, 880],
#            dtype='int64', name='PassengerId')

# %% [markdown]
# Checking Outliers of Fare

# %%
plt.boxplot(tit["Fare"])
plt.title("Checking outliers")
# Out:
# Text(0.5, 1.0, 'Checking outliers')

# %%
Q1 = np.percentile(tit["Fare"], 25)
Q2 = np.percentile(tit["Fare"], 50)
Q3 = np.percentile(tit["Fare"], 75)
IQR = Q3 - Q1
low_lim = Q1 - 1.5*IQR
Up_lim  = Q3 + 1.5*IQR

# %%
print(low_lim)
print(Up_lim)
# Out:
# -26.724
# 65.6344

# %%
Outlier= []
for j in tit["Fare"]:
    if((j > Up_lim)  or (j < low_lim)):
        Outlier.append(j)

# %%
Outlier
# Out:
# [71.2833,
#  263.0,
#  146.5208,
#  82.1708,
#  76.7292,
#  80.0,
#  83.475,
#  73.5,
#  263.0,
#  77.2875,
#  247.5208,
#  73.5,
#  77.2875,
#  79.2,
#  66.6,
#  69.55,
#  69.55,
#  146.5208,
#  69.55,
#  113.275,
#  76.2917,
#  90.0,
#  83.475,
#  90.0,
#  79.2,
#  86.5,
#  512.3292,
#  79.65,
#  153.4625,
#  135.6333,
#  77.9583,
#  78.85,
#  91.0792,
#  151.55,
#  247.5208,
#  151.55,
#  110.8833,
#  108.9,
#  83.1583,
#  262.375,
#  164.8667,
#  134.5,
#  69.55,
#  135.6333,
#  153.4625,
#  133.65,
#  66.6,
#  134.5,
#  263.0,
#  75.25,
#  69.3,
#  135.6333,
#  82.1708,
#  211.5,
#  227.525,
#  73.5,
#  120.0,
#  113.275,
#  90.0,
#  120.0,
#  263.0,
#  81.8583,
#  89.1042,
#  91.0792,
#  90.0,
#  78.2667,
#  151.55,
#  86.5,
#  108.9,
#  93.5,
#  221.7792,
#  106.425,
#  71.0,
#  106.425,
#  110.8833,
#  227.525,
#  79.65,
#  110.8833,
#  79.65,
#  79.2,
#  78.2667,
#  153.4625,
#  77.9583,
#  69.3,
#  76.7292,
#  73.5,
#  113.275,
#  133.65,
#  73.5,
#  512.3292,
#  76.7292,
# ...

# %%
ind_1 =tit["Fare"] > Up_lim
tit.loc[ind_1].index
# Out:
# Int64Index([  2,  28,  32,  35,  53,  62,  63,  73,  89, 103,
#             ...
#             793, 803, 821, 830, 836, 847, 850, 857, 864, 880],
#            dtype='int64', name='PassengerId', length=116)

# %% [markdown]
# Checking Outliers of SibSp

# %%
plt.boxplot(tit["SibSp"])
plt.title("Checking outliers")
# Out:
# Text(0.5, 1.0, 'Checking outliers')

# %%
Q1 = np.percentile(tit["SibSp"], 25)
Q2 = np.percentile(tit["SibSp"], 50)
Q3 = np.percentile(tit["SibSp"], 75)
IQR = Q3 - Q1
low_lim = Q1 - 1.5*IQR
Up_lim  = Q3 + 1.5*IQR

# %%
print(low_lim)
print(Up_lim)
# Out:
# -1.5
# 2.5

# %%
Outlier= []
for x in tit["SibSp"]:
    if((x > Up_lim)  or (x < low_lim)):
        Outlier.append(x)

# %%
Outlier
# Out:
# [3,
#  4,
#  3,
#  3,
#  4,
#  5,
#  3,
#  4,
#  5,
#  3,
#  3,
#  4,
#  8,
#  4,
#  4,
#  3,
#  8,
#  4,
#  8,
#  3,
#  4,
#  4,
#  4,
#  4,
#  8,
#  3,
#  3,
#  5,
#  3,
#  5,
#  3,
#  4,
#  4,
#  3,
#  3,
#  5,
#  4,
#  3,
#  4,
#  8,
#  4,
#  3,
#  4,
#  8,
#  4,
#  8]

# %%
ind_2 =tit["SibSp"] > Up_lim
tit.loc[ind_2].index
# Out:
# Int64Index([  8,  17,  25,  28,  51,  60,  64,  69,  72,  86,  89, 120, 160,
#             165, 172, 177, 181, 183, 202, 230, 234, 262, 267, 279, 325, 342,
#             375, 387, 410, 481, 486, 542, 543, 635, 643, 684, 687, 727, 788,
#             793, 814, 820, 825, 847, 851, 864],
#            dtype='int64', name='PassengerId')

# %% [markdown]
# # Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
tit["Survived"]
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
tit.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing

# %%
X = tit.drop("Survived", axis = 1)
Y = tit["Survived"]
min_max = preprocessing.MinMaxScaler(feature_range = (0,1))

# %%
X.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.836071   13.019697    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   35.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
X = pd.DataFrame(tit['Survived'])

# %%
X = min_max.fit_transform(X)

# %%
X = pd.DataFrame(X)

# %%
X.describe()
# Out:
#                 0
# count  891.000000
# mean     0.383838
# std      0.486592
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# Checking Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state = 42)
lr = linear_model.LinearRegression()
model = lr.fit(X_train,Y_train)
predictions = model.predict(X_test)
print("MSE is :",mean_squared_error(Y_test,predictions))
print("R squared value is :", r2_score(Y_test,predictions))
# Out:
# MSE is : 0.0
# R squared value is : 1.0
